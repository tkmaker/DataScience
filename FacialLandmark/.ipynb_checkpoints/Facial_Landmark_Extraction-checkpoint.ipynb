# %% [markdown]
# ### Facial Landmark/Keypoint Detection
#
# The dataset here is based on the Kaggle facial keypoint detection challenge:
# https://www.kaggle.com/c/facial-keypoints-detection

# %% [markdown]
# Let us import the dataset and visualize the facial keypoints
# The pickle files here were created by process.py run on the original Kaggle dataset.

# %%
import pickle
import time
from sklearn.metrics import roc_auc_score,roc_curve,auc
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Dense,Dropout,Conv2D,Activation,MaxPool2D,BatchNormalization,Flatten,Conv2DTranspose,Reshape,Input
from sklearn.model_selection import KFold
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.optimizers import Adam,SGD,RMSprop
from keras.models import Sequential
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split


IMAGE_WIDTH = 96
IMAGE_HEIGHT = 96

#Import dataset
with open('X.pickle','rb') as xfp:
    X = pickle.load(xfp)

with open('y.pickle','rb') as yfp:
    y = pickle.load(yfp)    

   
def show_image(X, Y):
    
    #Show image
    plt.imshow(X[:,:,0],cmap='gray')
    plt.show()
    
    #copy image - we dont want to alter the original
    img = np.copy(X)
    
    #Iterate through keypts and skip by 2  since they are stored in x,y pairs
    for i in range(0,Y.shape[0],2):
        #If y coord is part of image and x coord is part of image - change pixel color
        if 0 < Y[i+1] < IMAGE_HEIGHT and 0 < Y[i] < IMAGE_WIDTH:
            img[int(Y[i+1]),int(Y[i]),0] = 255
    
    #Show image with keypoints
    plt.imshow(img[:,:,0],cmap='gray')

# %% [markdown]
# ### Understanding the data
#
# The images have upto 15 landmarks (x,y) pairs corresponding to the yellow dots in the second image below.
#
# The 15 landmarks are:
#
# left_eye_center, right_eye_center, left_eye_inner_corner, left_eye_outer_corner, right_eye_inner_corner, right_eye_outer_corner, left_eyebrow_inner_end, left_eyebrow_outer_end, right_eyebrow_inner_end, right_eyebrow_outer_end, nose_tip, mouth_left_corner, mouth_right_corner, mouth_center_top_lip, mouth_center_bottom_lip
#
# So the task is to predict the 30 coordinates corresponding to the 15 landmarks.

# %%
show_image(X[20],y[20])

# %% [markdown]
# ### Model Definition
#
# We will use a Resnet50 model (https://arxiv.org/abs/1512.03385) as a baseline model for transfer learning with the fully connected layer removed. A custom deep fully connected network will be added on top of the ResNet50 model and stored as the final model.

# %%
def createResnetModel ():
    
    #baseline Resnet50 model
    base_model = ResNet50(include_top=False, input_tensor=Input(shape=(96,96,3)), pooling='avg')
    #Freeze all layers - we dont want to learn the weights here
    base_model.trainable = False
    
    
    #Top model added after Resnet
    
    #Model params
    
    #Define dropout value
    dropout  = 0.5
    #Kernel and Bias initializer
    kernel_init  = 'he_uniform'
    #Enable or disable Batch Normalization
    use_bn = False
    
    #Dense layer
    top_model = Sequential()
    top_model.add(Dense(512,  input_shape=(2048,),kernel_initializer=kernel_init))
    if use_bn:
        top_model.add(BatchNormalization())
    top_model.add(Activation('relu'))
    
    #Dense layer    
    top_model.add(Dense(256, kernel_initializer=kernel_init))
    if use_bn:
        top_model.add(BatchNormalization())
    top_model.add(Activation('relu'))

    #Dropout    
    top_model.add(Dropout(dropout))
    
    #Dense layer
    top_model.add(Dense(128, kernel_regularizer=regularizers.l2(0.01),kernel_initializer=kernel_init))
    if use_bn:
        top_model.add(BatchNormalization())
    top_model.add(Activation('relu'))
    
    #Dropout    
    top_model.add(Dropout(dropout))
    
    #Dense layer
    top_model.add(Dense(96, kernel_regularizer=regularizers.l2(0.01),kernel_initializer=kernel_init))
    if use_bn:
        top_model.add(BatchNormalization())
    top_model.add(Activation('relu'))
    
    #Dropout    
    top_model.add(Dropout(dropout))
    
    top_model.add(Dense(48, kernel_regularizer=regularizers.l2(0.01),kernel_initializer=kernel_init))
    if use_bn:
        top_model.add(BatchNormalization())
    top_model.add(Activation('relu'))
    
    
    top_model.add(Dense(30))
    
    top_model.compile(loss='mse', optimizer=Adam(0.001), metrics=['mae'])
    
    #Combine models
    final_model = Sequential([base_model, top_model])
    final_model.compile(loss='mse', optimizer=Adam(0.001), metrics=['mae'])
    final_model.summary()

    return final_model

# %%
def trainModel (datagen, model, X, y):
       
        print ("Training model \n")
        
        
        X_train,X_val,y_train,y_val = train_test_split(X,y,test_size = 0.2, shuffle=True)
      

        #Use early stopping to avoid overfit
        earlystop = EarlyStopping(patience=early_stop_epochs,monitor='val_loss')
        reduce_lr =  ReduceLROnPlateau(monitor='loss', factor=0.1, \
                                       verbose=verbose,  mode='min')
        
        callbacks_list = [earlystop,reduce_lr]
        
        #track model training time
        start_time = time.time()

        generator = datagen.flow(X_train, y_train, batch_size = batch_size)

        # Fitting the model to the training set
        model_info =  model.fit_generator(
                generator,
                steps_per_epoch=batch_size,
                epochs=epochs,
                shuffle=True,
                verbose=verbose,
                validation_data = (X_val, y_val),
                callbacks = callbacks_list)
            
        # plot model history
        plot_model_history(model_info,'mean_absolute_error','val_mean_absolute_error')
   
        #Evaluate the model
        scores = model.evaluate(X_val,y_val)
        print("\n%s: %.2f\n" % (model.metrics_names[1],scores[1]))
 
         

        end_time = time.time()
        train_time = (end_time - start_time)/60
  
        print("Model train time = %f minutes" % train_time)
        
        
def trainModelKfold (datagen, model, X, y):
       
        print ("Training model using K-Fold cross val\n")
        
     
        
        #K-Fold Cross validation
        kf = KFold(n_splits=5,shuffle=True, random_state=1) 

        #Store cross val scores
        cv_scores = []

        #Use early stopping to avoid overfit
        earlystop = EarlyStopping(patience=early_stop_epochs,monitor='val_loss')
        reduce_lr =  ReduceLROnPlateau(monitor='loss', factor=0.1, \
                                       verbose=verbose,  mode='min')
        
        callbacks_list = [earlystop,reduce_lr]
        
        #track model training time
        start_time = time.time()

        #Do k-fold cross val across dataset and store scores
        for train_index, val_index in kf.split(X):
            
            
            X_train, X_val = X[train_index], X[val_index]
            y_train, y_val = y[train_index], y[val_index]

            generator = datagen.flow(X_train, y_train, batch_size = batch_size)

            # Fitting the model to the training set
            model_info =  model.fit_generator(
                generator,
                steps_per_epoch=batch_size,
                epochs=epochs,
                shuffle=True,
                verbose=verbose,
                validation_data = (X_val, y_val),
                callbacks = callbacks_list)
            
            # plot model history
            plot_model_history(model_info,'mean_absolute_error','val_mean_absolute_error')
   
            #Evaluate the model
            scores = model.evaluate(X_val,y_val)
            print("\n%s: %.2f%%\n" % (model.metrics_names[1],scores[1]*100))
            cv_scores.append(scores[1]*100)
 
         

        end_time = time.time()
        train_time = (end_time - start_time)/60
  
        print("Model train time = %f minutes" % train_time)
        print("Overall Accuracy = %.2f%% (+/- %.2f%%)" % (np.mean(cv_scores), np.std(cv_scores)))

    


def plot_model_history(model_history,train_metric,val_metric):
        
        fig, axs = plt.subplots(1,2,figsize=(15,5))
        
        # summarize history for accuracy
        axs[0].plot(range(1,len(model_history.history[train_metric])+1),model_history.history[train_metric])
        axs[0].plot(range(1,len(model_history.history[val_metric])+1),model_history.history[val_metric])
        axs[0].set_title(train_metric)
        axs[0].set_ylabel(train_metric)
        axs[0].set_xlabel('Epoch')
        axs[0].set_xticks(np.arange(1,len(model_history.history[train_metric])+1),len(model_history.history[train_metric])/10)
        axs[0].legend(['train', 'val'], loc='best')
        
        # summarize history for loss
        axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
        axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
        axs[1].set_title('Model Loss')
        axs[1].set_ylabel('Loss')
        axs[1].set_xlabel('Epoch')
        axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
        axs[1].legend(['train', 'val'], loc='best')
        plt.show()

# %% [markdown]
# ### Data Augmentation
#
# The Keras ImageDataGenerator class will be used to augment the images. Below is the starting point, where we use width and height pixel shifts along with pixel value rescaling between 0-1.

# %%
#Data augmentation    
train_datagen = ImageDataGenerator(
        #rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        #shear_range=0.2,
        #zoom_range=0.2,
        #horizontal_flip=True,
        #fill_mode='nearest'
        )

#Model hyper params
epochs  = 100
batch_size = 32
early_stop_epochs = 25
verbose = True

#Baseline images are 1 channel. Convert to 3 channel 
x = np.array([ X[:,:,:,0],X[:,:,:,0],X[:,:,:,0]])

#Move axes to match (batches,width,height,channels)
x = np.swapaxes(x,0,1)
x = np.swapaxes(x,1,2)
x = np.swapaxes(x,2,3)

# %%
#Create Resnet based model
model = createResnetModel()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 30)                1231822
# =================================================================
# Total params: 24,819,534
# Trainable params: 1,231,822
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
#Train model 
trainModel(train_datagen,model,x,y)
# Out:
# Training model
#
# Epoch 1/100
# 32/32 [==============================] - 367s 11s/step - loss: 301.5679 - mean_absolute_error: 13.3992 - val_loss: 296.0088 - val_mean_absolute_error: 14.0722
# Epoch 2/100
# 32/32 [==============================] - 339s 11s/step - loss: 274.3680 - mean_absolute_error: 12.7822 - val_loss: 621.2570 - val_mean_absolute_error: 21.8708
# Epoch 3/100
# 32/32 [==============================] - 364s 11s/step - loss: 254.9951 - mean_absolute_error: 12.2411 - val_loss: 208.1640 - val_mean_absolute_error: 12.0108
# Epoch 4/100
# 32/32 [==============================] - 360s 11s/step - loss: 241.3226 - mean_absolute_error: 11.9320 - val_loss: 208.6056 - val_mean_absolute_error: 11.5144
# Epoch 5/100
# 32/32 [==============================] - 350s 11s/step - loss: 256.3174 - mean_absolute_error: 12.2089 - val_loss: 53.9005 - val_mean_absolute_error: 5.2616
# Epoch 6/100
# 32/32 [==============================] - 359s 11s/step - loss: 240.0072 - mean_absolute_error: 11.7024 - val_loss: 250.4413 - val_mean_absolute_error: 13.2674
# Epoch 7/100
# 32/32 [==============================] - 348s 11s/step - loss: 228.9401 - mean_absolute_error: 11.5487 - val_loss: 260.4373 - val_mean_absolute_error: 13.4882
# Epoch 8/100
# 32/32 [==============================] - 352s 11s/step - loss: 186.4917 - mean_absolute_error: 10.4161 - val_loss: 138.6281 - val_mean_absolute_error: 9.1928
# Epoch 9/100
# 32/32 [==============================] - 365s 11s/step - loss: 200.9021 - mean_absolute_error: 10.6967 - val_loss: 278.5058 - val_mean_absolute_error: 13.8272
# Epoch 10/100
# 32/32 [==============================] - 376s 12s/step - loss: 187.1561 - mean_absolute_error: 10.3134 - val_loss: 58.5247 - val_mean_absolute_error: 5.5954
# Epoch 11/100
# 32/32 [==============================] - 375s 12s/step - loss: 174.7317 - mean_absolute_error: 9.9888 - val_loss: 447.3245 - val_mean_absolute_error: 18.4456
# Epoch 12/100
# 32/32 [==============================] - 377s 12s/step - loss: 181.7349 - mean_absolute_error: 10.2450 - val_loss: 185.3945 - val_mean_absolute_error: 11.2661
# Epoch 13/100
# 32/32 [==============================] - 372s 12s/step - loss: 179.3066 - mean_absolute_error: 9.9986 - val_loss: 34.8837 - val_mean_absolute_error: 4.1972
# Epoch 14/100
# 32/32 [==============================] - 381s 12s/step - loss: 176.5783 - mean_absolute_error: 9.9470 - val_loss: 110.2039 - val_mean_absolute_error: 8.3087
# Epoch 15/100
# 32/32 [==============================] - 378s 12s/step - loss: 160.6524 - mean_absolute_error: 9.5605 - val_loss: 357.9814 - val_mean_absolute_error: 16.4339
# Epoch 16/100
# 32/32 [==============================] - 373s 12s/step - loss: 154.0519 - mean_absolute_error: 9.3457 - val_loss: 332.0931 - val_mean_absolute_error: 15.7533
# Epoch 17/100
# 32/32 [==============================] - 365s 11s/step - loss: 155.4930 - mean_absolute_error: 9.2803 - val_loss: 105.5672 - val_mean_absolute_error: 8.0071
# Epoch 18/100
# 32/32 [==============================] - 376s 12s/step - loss: 160.2187 - mean_absolute_error: 9.4570 - val_loss: 97.9325 - val_mean_absolute_error: 7.6169
# Epoch 19/100
# 32/32 [==============================] - 362s 11s/step - loss: 149.5112 - mean_absolute_error: 9.1763 - val_loss: 202.8587 - val_mean_absolute_error: 11.6556
# Epoch 20/100
# 32/32 [==============================] - 353s 11s/step - loss: 143.0412 - mean_absolute_error: 9.0051 - val_loss: 148.7589 - val_mean_absolute_error: 9.8186
# Epoch 21/100
# 32/32 [==============================] - 379s 12s/step - loss: 137.5707 - mean_absolute_error: 8.7241 - val_loss: 164.4125 - val_mean_absolute_error: 10.3323
# Epoch 22/100
# 32/32 [==============================] - 370s 12s/step - loss: 136.8979 - mean_absolute_error: 8.6836 - val_loss: 48.2113 - val_mean_absolute_error: 4.9471
# Epoch 23/100
# 32/32 [==============================] - 372s 12s/step - loss: 131.4659 - mean_absolute_error: 8.5178 - val_loss: 50.8985 - val_mean_absolute_error: 4.9762
# Epoch 24/100
# 32/32 [==============================] - 358s 11s/step - loss: 131.3599 - mean_absolute_error: 8.5868 - val_loss: 60.3686 - val_mean_absolute_error: 5.6201
# Epoch 25/100
# 32/32 [==============================] - 344s 11s/step - loss: 120.6504 - mean_absolute_error: 8.2510 - val_loss: 43.6447 - val_mean_absolute_error: 4.6082
# Epoch 26/100
# 32/32 [==============================] - 360s 11s/step - loss: 116.5614 - mean_absolute_error: 8.0270 - val_loss: 154.3794 - val_mean_absolute_error: 10.2269
# Epoch 27/100
# 32/32 [==============================] - 378s 12s/step - loss: 113.7943 - mean_absolute_error: 7.9199 - val_loss: 78.1557 - val_mean_absolute_error: 6.7642
# Epoch 28/100
# 32/32 [==============================] - 366s 11s/step - loss: 114.5809 - mean_absolute_error: 8.0198 - val_loss: 52.1148 - val_mean_absolute_error: 5.2164
# Epoch 29/100
# 32/32 [==============================] - 362s 11s/step - loss: 107.6649 - mean_absolute_error: 7.7235 - val_loss: 80.6757 - val_mean_absolute_error: 6.7768
# Epoch 30/100
# 32/32 [==============================] - 374s 12s/step - loss: 102.6492 - mean_absolute_error: 7.4840 - val_loss: 106.2165 - val_mean_absolute_error: 8.1122
# Epoch 31/100
# 32/32 [==============================] - 379s 12s/step - loss: 99.8618 - mean_absolute_error: 7.3851 - val_loss: 27.3252 - val_mean_absolute_error: 3.5661
# Epoch 32/100
# 32/32 [==============================] - 367s 11s/step - loss: 90.5430 - mean_absolute_error: 7.0603 - val_loss: 46.4287 - val_mean_absolute_error: 5.0225
# Epoch 33/100
# 32/32 [==============================] - 383s 12s/step - loss: 87.1912 - mean_absolute_error: 6.8843 - val_loss: 29.2035 - val_mean_absolute_error: 3.7715
# Epoch 34/100
# 32/32 [==============================] - 372s 12s/step - loss: 76.1653 - mean_absolute_error: 6.4124 - val_loss: 56.9144 - val_mean_absolute_error: 5.7463
# Epoch 35/100
# 32/32 [==============================] - 366s 11s/step - loss: 80.6764 - mean_absolute_error: 6.6405 - val_loss: 26.3034 - val_mean_absolute_error: 3.4875
# Epoch 36/100
# 32/32 [==============================] - 383s 12s/step - loss: 80.5547 - mean_absolute_error: 6.5800 - val_loss: 41.3943 - val_mean_absolute_error: 4.5953
# Epoch 37/100
# 32/32 [==============================] - 370s 12s/step - loss: 70.3517 - mean_absolute_error: 6.1871 - val_loss: 25.0480 - val_mean_absolute_error: 3.3746
# Epoch 38/100
# 32/32 [==============================] - 366s 11s/step - loss: 69.1174 - mean_absolute_error: 6.1103 - val_loss: 27.9283 - val_mean_absolute_error: 3.7084
# Epoch 39/100
# 32/32 [==============================] - 373s 12s/step - loss: 69.8254 - mean_absolute_error: 6.0994 - val_loss: 21.5342 - val_mean_absolute_error: 3.1277
# Epoch 40/100
# 32/32 [==============================] - 368s 12s/step - loss: 65.2689 - mean_absolute_error: 5.8880 - val_loss: 20.5835 - val_mean_absolute_error: 3.0295
# Epoch 41/100
# 32/32 [==============================] - 371s 12s/step - loss: 63.8903 - mean_absolute_error: 5.8026 - val_loss: 18.9291 - val_mean_absolute_error: 2.8892
# Epoch 42/100
# 32/32 [==============================] - 9444s 295s/step - loss: 60.1564 - mean_absolute_error: 5.7382 - val_loss: 20.4096 - val_mean_absolute_error: 3.0139
# Epoch 43/100
# 32/32 [==============================] - 345s 11s/step - loss: 57.1695 - mean_absolute_error: 5.4971 - val_loss: 78.3785 - val_mean_absolute_error: 6.7582
# Epoch 44/100
# 32/32 [==============================] - 355s 11s/step - loss: 56.8714 - mean_absolute_error: 5.4813 - val_loss: 26.7926 - val_mean_absolute_error: 3.5673
# Epoch 45/100
# 32/32 [==============================] - 378s 12s/step - loss: 57.7646 - mean_absolute_error: 5.5776 - val_loss: 21.3902 - val_mean_absolute_error: 3.1342
# Epoch 46/100
# 32/32 [==============================] - 368s 12s/step - loss: 53.7268 - mean_absolute_error: 5.3204 - val_loss: 23.2543 - val_mean_absolute_error: 3.3903
# Epoch 47/100
# 32/32 [==============================] - 347s 11s/step - loss: 54.3438 - mean_absolute_error: 5.3231 - val_loss: 24.1431 - val_mean_absolute_error: 3.4984
# Epoch 48/100
# 32/32 [==============================] - 338s 11s/step - loss: 57.3497 - mean_absolute_error: 5.5304 - val_loss: 20.5270 - val_mean_absolute_error: 3.1312
# Epoch 49/100
# 32/32 [==============================] - 334s 10s/step - loss: 55.2654 - mean_absolute_error: 5.4354 - val_loss: 21.6833 - val_mean_absolute_error: 3.2681
# Epoch 50/100
# 32/32 [==============================] - 341s 11s/step - loss: 52.9299 - mean_absolute_error: 5.3029 - val_loss: 23.2499 - val_mean_absolute_error: 3.4822
# Epoch 51/100
# 32/32 [==============================] - 357s 11s/step - loss: 54.5124 - mean_absolute_error: 5.3927 - val_loss: 20.6891 - val_mean_absolute_error: 3.1858
# Epoch 52/100
# 32/32 [==============================] - 348s 11s/step - loss: 53.2485 - mean_absolute_error: 5.2755 - val_loss: 29.7944 - val_mean_absolute_error: 4.1666
# Epoch 53/100
# 32/32 [==============================] - 346s 11s/step - loss: 52.6768 - mean_absolute_error: 5.2945 - val_loss: 18.6946 - val_mean_absolute_error: 2.9281
# Epoch 54/100
# 32/32 [==============================] - 363s 11s/step - loss: 50.8810 - mean_absolute_error: 5.1499 - val_loss: 25.4395 - val_mean_absolute_error: 3.7337
# Epoch 55/100
# 32/32 [==============================] - 366s 11s/step - loss: 50.1633 - mean_absolute_error: 5.1259 - val_loss: 23.3238 - val_mean_absolute_error: 3.4807
# Epoch 56/100
# 32/32 [==============================] - 355s 11s/step - loss: 47.9259 - mean_absolute_error: 5.0338 - val_loss: 26.7724 - val_mean_absolute_error: 3.8911
# Epoch 57/100
# 32/32 [==============================] - 355s 11s/step - loss: 46.4419 - mean_absolute_error: 4.9029 - val_loss: 35.4346 - val_mean_absolute_error: 4.7095
# Epoch 58/100
# 32/32 [==============================] - 365s 11s/step - loss: 48.9065 - mean_absolute_error: 5.0601 - val_loss: 29.2534 - val_mean_absolute_error: 4.1494
# Epoch 59/100
# 32/32 [==============================] - 356s 11s/step - loss: 50.5626 - mean_absolute_error: 5.1765 - val_loss: 27.5651 - val_mean_absolute_error: 3.9935
# Epoch 60/100
# 32/32 [==============================] - 357s 11s/step - loss: 47.0912 - mean_absolute_error: 5.0002 - val_loss: 27.3448 - val_mean_absolute_error: 3.9402
# Epoch 61/100
# 32/32 [==============================] - 375s 12s/step - loss: 47.1370 - mean_absolute_error: 4.9586 - val_loss: 24.7986 - val_mean_absolute_error: 3.7270
# Epoch 62/100
# 32/32 [==============================] - 466s 15s/step - loss: 47.4596 - mean_absolute_error: 4.9990 - val_loss: 15.0516 - val_mean_absolute_error: 2.5187
# Epoch 63/100
# 32/32 [==============================] - 367s 11s/step - loss: 44.5139 - mean_absolute_error: 4.8020 - val_loss: 22.9335 - val_mean_absolute_error: 3.5181
# Epoch 64/100
# 32/32 [==============================] - 373s 12s/step - loss: 45.6629 - mean_absolute_error: 4.9054 - val_loss: 25.2834 - val_mean_absolute_error: 3.7723
# Epoch 65/100
# 32/32 [==============================] - 369s 12s/step - loss: 44.5774 - mean_absolute_error: 4.8157 - val_loss: 28.7472 - val_mean_absolute_error: 4.0400
# Epoch 66/100
# 32/32 [==============================] - 406s 13s/step - loss: 42.6866 - mean_absolute_error: 4.7548 - val_loss: 22.7259 - val_mean_absolute_error: 3.4903
# Epoch 67/100
# 32/32 [==============================] - 396s 12s/step - loss: 45.9458 - mean_absolute_error: 4.8949 - val_loss: 28.6795 - val_mean_absolute_error: 4.0785
# Epoch 68/100
# 32/32 [==============================] - 346s 11s/step - loss: 45.6610 - mean_absolute_error: 4.9200 - val_loss: 28.5741 - val_mean_absolute_error: 4.0798
# Epoch 69/100
# 32/32 [==============================] - 339s 11s/step - loss: 44.7941 - mean_absolute_error: 4.8656 - val_loss: 15.1747 - val_mean_absolute_error: 2.5564
# Epoch 70/100
# 32/32 [==============================] - 351s 11s/step - loss: 44.8592 - mean_absolute_error: 4.8569 - val_loss: 21.8578 - val_mean_absolute_error: 3.3817
# Epoch 71/100
# 32/32 [==============================] - 346s 11s/step - loss: 43.0561 - mean_absolute_error: 4.7359 - val_loss: 23.3018 - val_mean_absolute_error: 3.5429
# Epoch 72/100
# 32/32 [==============================] - 523s 16s/step - loss: 43.6610 - mean_absolute_error: 4.7434 - val_loss: 21.0753 - val_mean_absolute_error: 3.3232
# Epoch 73/100
# 32/32 [==============================] - 492s 15s/step - loss: 41.1333 - mean_absolute_error: 4.6555 - val_loss: 21.5282 - val_mean_absolute_error: 3.3843
# Epoch 74/100
# 32/32 [==============================] - 394s 12s/step - loss: 45.5385 - mean_absolute_error: 4.8788 - val_loss: 23.9405 - val_mean_absolute_error: 3.6560
# Epoch 75/100
# 32/32 [==============================] - 465s 15s/step - loss: 44.0602 - mean_absolute_error: 4.7695 - val_loss: 17.8845 - val_mean_absolute_error: 2.9266
# Epoch 76/100
# 32/32 [==============================] - 367s 11s/step - loss: 44.0290 - mean_absolute_error: 4.8081 - val_loss: 39.7488 - val_mean_absolute_error: 5.1240
# Epoch 77/100
# 32/32 [==============================] - 367s 11s/step - loss: 41.1865 - mean_absolute_error: 4.6111 - val_loss: 16.7752 - val_mean_absolute_error: 2.7824
# Epoch 78/100
# 32/32 [==============================] - 394s 12s/step - loss: 38.8637 - mean_absolute_error: 4.4845 - val_loss: 32.9404 - val_mean_absolute_error: 4.5052
# Epoch 79/100
# 32/32 [==============================] - 424s 13s/step - loss: 40.2829 - mean_absolute_error: 4.5491 - val_loss: 27.1400 - val_mean_absolute_error: 3.9490
# Epoch 80/100
# 32/32 [==============================] - 438s 14s/step - loss: 41.1407 - mean_absolute_error: 4.6331 - val_loss: 17.3822 - val_mean_absolute_error: 2.8543
# Epoch 81/100
# 32/32 [==============================] - 433s 14s/step - loss: 41.1633 - mean_absolute_error: 4.6522 - val_loss: 18.5568 - val_mean_absolute_error: 2.9714
# Epoch 82/100
# 32/32 [==============================] - 390s 12s/step - loss: 42.1167 - mean_absolute_error: 4.7049 - val_loss: 23.6818 - val_mean_absolute_error: 3.5209
# Epoch 83/100
# 32/32 [==============================] - 383s 12s/step - loss: 38.9259 - mean_absolute_error: 4.5164 - val_loss: 23.6027 - val_mean_absolute_error: 3.5857
# Epoch 84/100
# 32/32 [==============================] - 387s 12s/step - loss: 37.4298 - mean_absolute_error: 4.3986 - val_loss: 21.1308 - val_mean_absolute_error: 3.3394
# Epoch 85/100
# 32/32 [==============================] - 413s 13s/step - loss: 38.5411 - mean_absolute_error: 4.4924 - val_loss: 25.1023 - val_mean_absolute_error: 3.7953
# Epoch 86/100
# 32/32 [==============================] - 386s 12s/step - loss: 37.8401 - mean_absolute_error: 4.4024 - val_loss: 24.3864 - val_mean_absolute_error: 3.7049
# Epoch 87/100
# 32/32 [==============================] - 400s 12s/step - loss: 36.9942 - mean_absolute_error: 4.4164 - val_loss: 18.0856 - val_mean_absolute_error: 2.9357
# 428/428 [==============================] - 146s 341ms/step
#
# mean_absolute_error: 2.94
#
# Model train time = 696.820148 minutes

# %%
#Save model                   
model.save('resnet_transfer.h5')

# %% [markdown]
# ### Visualizing predictions
#
# Let us define a function to show the true keypoints alongside the predicted ones.

# %%
def show_predictions(X, Y,Y_true):
    
   
    
    #copy image - we dont want to alter the original
    img = np.copy(X)
    
    ###Predicted labels
    
    #Iterate through keypts and skip by 2  since they are stored in x,y pairs
    for i in range(0,Y.shape[0],2):
        #If y coord is part of image and x coord is part of image - change pixel color
        if 0 < Y[i+1] < IMAGE_HEIGHT and 0 < Y[i] < IMAGE_WIDTH:
            img[int(Y[i+1]),int(Y[i]),0] = 255
    
    ###Ground truth
    #Iterate through keypts and skip by 2  since they are stored in x,y pairs
    for i in range(0,Y_true.shape[0],2):
        #If y coord is part of image and x coord is part of image - change pixel color
        if 0 < Y_true[i+1] < IMAGE_HEIGHT and 0 < Y_true[i] < IMAGE_WIDTH:
            img[int(Y_true[i+1]),int(Y_true[i]),0] = 3
            
    #Show image with keypoints
    plt.imshow(img[:,:,0],cmap='gray')

# %%
with open('X_test.pickle','rb') as f:
    X_test = pickle.load(f)
    
#Baseline images are 1 channel. Convert to 3 channel 
x_test = np.array([ X_test[:,:,:,0],X_test[:,:,:,0],X_test[:,:,:,0]])

#Move axes to match (batches,width,height,channels)
x_test = np.swapaxes(x_test,0,1)
x_test = np.swapaxes(x_test,1,2)
x_test = np.swapaxes(x_test,2,3)


with open('X.pickle','rb') as f:
    X = pickle.load(f)
   
with open('y.pickle','rb') as f:
    y = pickle.load(f)
    
#Baseline images are 1 channel. Convert to 3 channel 
x = np.array([ X[:,:,:,0],X[:,:,:,0],X[:,:,:,0]])

#Move axes to match (batches,width,height,channels)
x = np.swapaxes(x,0,1)
x = np.swapaxes(x,1,2)
x = np.swapaxes(x,2,3)

# %%
#Select image index here
img_indx = 33

#Get prediction and dsiaply results
y_pred = model.predict(x[img_indx:(img_indx+1)])
y_true = y[img_indx:(img_indx+1)]

show_predictions(x[img_indx], y_pred[0],y_true[0])

# %% [markdown]
# You can see that the yellow (predicted) and black (actual) keypoints align pretty closely. We could optimize the model hyperparams and experiment with more data augmentation to achieve better results here.
